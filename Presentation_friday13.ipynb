# %%
from IPython.display import Audio

# %% [markdown]
# ## Lisening audio

# %%
# The link points to a database of audio files
Audio(url="http://www.w3schools.com/html/horse.ogg")
# Out:
#                 <audio  controls="controls" >
#                     <source src="http://www.w3schools.com/html/horse.ogg" type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Image

# %%
Image('https://strathmore.edu/wp-content/themes/michigan/images/logo.png')

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('w3ebQK7evbw', width=400, height=300)

# %%
Video
# Out:
# IPython.core.display.Video

# %%
? IPython.core.display.Video
# Out:
# Object ` IPython.core.display.Video` not found.
